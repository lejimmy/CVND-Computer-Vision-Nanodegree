# %% [markdown]
# # Images as Grids of Pixels

# %% [markdown]
# ### Import resources

# %%
import numpy as np
import matplotlib.image as mpimg # for reading in images
import matplotlib.pyplot as plt
import cv2 # compute vision library

# %% [markdown]
# ### Read in and display the image

# %%
# read in the image
image = mpimg.imread('https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/screen-shot-2018-03-27-at-1-46-26-pm-1522172809.png?crop=0.9913309535951046xw:1xh;center,top&resize=480:*')

# print out the image dimensions
print(f'Image Dimensions: {image.shape}')
# Out:
# Image Dimensions: (240, 480, 4)

# %%
# change from color to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# plot image
plt.figure(figsize = (10, 12))
plt.imshow(gray_image, cmap = 'gray');

# %%
# Print specific grayscale pixel values
# What is the pixel value at x = 300 and y = 200 (on the body of the car)?

x = 300
y = 200

print(gray_image[y,x])
# Out:
# 0.09432942

# %%
pixel_val = gray_image[y, x]
print(pixel_val)
# Out:
# 0.09432942

# %%
#Find the maximum and minimum grayscale values in this image

max_val = np.amax(gray_image)
min_val = np.amin(gray_image)

print('Max: ', max_val)
print('Min: ', min_val)

# %%
# Create a 5x5 image using just grayscale, numerical values
tiny_image = np.array([[0, 20, 30, 150, 120],
                      [200, 200, 250, 70, 3],
                      [50, 180, 85, 40, 90],
                      [240, 100, 50, 255, 10],
                      [30, 0, 75, 190, 220]])

# To show the pixel grid, use matshow
plt.matshow(tiny_image, cmap='gray')

## TODO: See if you can draw a tiny smiley face or something else!
